# %%
import json
import numpy as np
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import time

# %%
DATA_PATH = "../data/all_mfcc_normal.json"
TRAIN_PATH = "../data/train_mfcc_normal.json"
TEST_PATH = "../data/test_mfcc_normal.json"
VAL_PATH = "../data/val_mfcc_normal.json"

# %%
def load_all_data(data_path):
    """Loads train dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return  X, y

# %%
def load_train_data(train_path):
    """Loads train dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(train_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X_tr = np.array(data["mfcc"])
    y_tr = np.array(data["labels"])

    print("Train Data succesfully loaded!")

    return  X_tr, y_tr

# %%
def load_test_data(test_path):
    """Loads test dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(test_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X_ts = np.array(data["mfcc"])
    y_ts = np.array(data["labels"])

    print("Test Data succesfully loaded!")

    return  X_ts, y_ts

# %%
def load_val_data(val_path):
    """Loads validation dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(val_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X_v = np.array(data["mfcc"])
    y_v = np.array(data["labels"])

    print("Validation Data succesfully loaded!")

    return  X_v, y_v

# %%
def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %%
def plot(history, epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def prepare_datasets():
    """
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    #X, y = load_all_data(DATA_PATH)

    # create train, validation and test split
    X_train, y_train = load_train_data(TRAIN_PATH)
    X_test, y_test = load_test_data(TEST_PATH)
    X_val, y_val = load_val_data(VAL_PATH)

    
    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_val = X_val[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
def build_model(input_shape):
    """Generates CNN model
    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (1, 1), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((1, 1), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())
    

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (1, 1), activation='relu'))
    model.add(keras.layers.MaxPooling2D((1, 1), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (1, 1), activation='relu'))
    model.add(keras.layers.MaxPooling2D((1, 1), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())
    

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(2, activation='softmax'))

    return model

# %%
def predict(model, X, y):
    """Predict a single sample using the trained model
    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))

# %%
X_train, X_val, X_test, y_train, y_val, y_test = prepare_datasets()
# Out:
# Train Data succesfully loaded!
# Test Data succesfully loaded!
# Validation Data succesfully loaded!

# %%
X_train.shape
# Out:
# (9600, 1, 13, 1)

# %%
if __name__ == "__main__":
    
    startTime = time.time()


    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets()
    print(X_train.shape)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=50)

    # plot accuracy/error for training and validation
    plot_history(history)
    plot(history, 50)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[50]
    y_to_predict = y_test[50]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
    
    
    executionTime = (time.time() - startTime)
    print('Execution time in seconds: ' + str(executionTime))
# Out:
# Train Data succesfully loaded!
# Test Data succesfully loaded!
# Validation Data succesfully loaded!
# (9600, 1, 13, 1)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 1, 13, 32)         64
#
#  max_pooling2d (MaxPooling2D  (None, 1, 7, 32)         0
#  )
#
#  batch_normalization (BatchN  (None, 1, 7, 32)         128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 1, 7, 32)          1056
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 4, 32)         0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 1, 4, 32)         128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 1, 4, 32)          1056
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 2, 32)         0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 1, 2, 32)         128
#  hNormalization)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 6,850
# Trainable params: 6,658
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/50
# 300/300 [==============================] - 5s 10ms/step - loss: 0.7407 - accuracy: 0.5321 - val_loss: 0.6855 - val_accuracy: 0.5777
# Epoch 2/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.7064 - accuracy: 0.5540 - val_loss: 0.6523 - val_accuracy: 0.6083
# Epoch 3/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6832 - accuracy: 0.5698 - val_loss: 0.6480 - val_accuracy: 0.6177
# Epoch 4/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6744 - accuracy: 0.5782 - val_loss: 0.6453 - val_accuracy: 0.6107
# Epoch 5/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6687 - accuracy: 0.5876 - val_loss: 0.6511 - val_accuracy: 0.6040
# Epoch 6/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6658 - accuracy: 0.5886 - val_loss: 0.6439 - val_accuracy: 0.6177
# Epoch 7/50
# 300/300 [==============================] - 2s 8ms/step - loss: 0.6603 - accuracy: 0.5893 - val_loss: 0.6408 - val_accuracy: 0.6213
# Epoch 8/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6617 - accuracy: 0.5947 - val_loss: 0.6466 - val_accuracy: 0.6140
# Epoch 9/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6601 - accuracy: 0.5927 - val_loss: 0.6451 - val_accuracy: 0.6147
# Epoch 10/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6569 - accuracy: 0.5990 - val_loss: 0.6436 - val_accuracy: 0.6200
# Epoch 11/50
# 300/300 [==============================] - 3s 11ms/step - loss: 0.6559 - accuracy: 0.6014 - val_loss: 0.6430 - val_accuracy: 0.6120
# Epoch 12/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6563 - accuracy: 0.5951 - val_loss: 0.6427 - val_accuracy: 0.6203
# Epoch 13/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6568 - accuracy: 0.6014 - val_loss: 0.6423 - val_accuracy: 0.6227
# Epoch 14/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6516 - accuracy: 0.6027 - val_loss: 0.6469 - val_accuracy: 0.6087
# Epoch 15/50
# 300/300 [==============================] - 3s 11ms/step - loss: 0.6531 - accuracy: 0.6037 - val_loss: 0.6416 - val_accuracy: 0.6220
# Epoch 16/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6524 - accuracy: 0.6052 - val_loss: 0.6413 - val_accuracy: 0.6127
# Epoch 17/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6532 - accuracy: 0.5997 - val_loss: 0.6417 - val_accuracy: 0.6137
# Epoch 18/50
# 300/300 [==============================] - 3s 8ms/step - loss: 0.6521 - accuracy: 0.6068 - val_loss: 0.6469 - val_accuracy: 0.6003
# Epoch 19/50
# 300/300 [==============================] - 3s 8ms/step - loss: 0.6524 - accuracy: 0.6040 - val_loss: 0.6425 - val_accuracy: 0.6203
# Epoch 20/50
# 300/300 [==============================] - 3s 11ms/step - loss: 0.6502 - accuracy: 0.6051 - val_loss: 0.6408 - val_accuracy: 0.6173
# Epoch 21/50
# 300/300 [==============================] - 3s 8ms/step - loss: 0.6498 - accuracy: 0.6069 - val_loss: 0.6371 - val_accuracy: 0.6213
# Epoch 22/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6524 - accuracy: 0.6058 - val_loss: 0.6462 - val_accuracy: 0.6057
# Epoch 23/50
# 300/300 [==============================] - 2s 7ms/step - loss: 0.6512 - accuracy: 0.6068 - val_loss: 0.6404 - val_accuracy: 0.6197
# Epoch 24/50
# 300/300 [==============================] - 2s 8ms/step - loss: 0.6519 - accuracy: 0.6045 - val_loss: 0.6406 - val_accuracy: 0.6240
# Epoch 25/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6494 - accuracy: 0.6065 - val_loss: 0.6382 - val_accuracy: 0.6170
# Epoch 26/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6515 - accuracy: 0.6046 - val_loss: 0.6461 - val_accuracy: 0.6067
# Epoch 27/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6513 - accuracy: 0.6091 - val_loss: 0.6455 - val_accuracy: 0.6080
# Epoch 28/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6472 - accuracy: 0.6108 - val_loss: 0.6402 - val_accuracy: 0.6163
# Epoch 29/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6494 - accuracy: 0.6054 - val_loss: 0.6394 - val_accuracy: 0.6163
# Epoch 30/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6476 - accuracy: 0.6120 - val_loss: 0.6441 - val_accuracy: 0.6143
# Epoch 31/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6501 - accuracy: 0.6049 - val_loss: 0.6409 - val_accuracy: 0.6193
# Epoch 32/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6488 - accuracy: 0.6092 - val_loss: 0.6447 - val_accuracy: 0.6203
# Epoch 33/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6493 - accuracy: 0.6105 - val_loss: 0.6425 - val_accuracy: 0.6233
# Epoch 34/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6471 - accuracy: 0.6073 - val_loss: 0.6424 - val_accuracy: 0.6160
# Epoch 35/50
# 300/300 [==============================] - 2s 7ms/step - loss: 0.6472 - accuracy: 0.6108 - val_loss: 0.6430 - val_accuracy: 0.6143
# Epoch 36/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6474 - accuracy: 0.6070 - val_loss: 0.6421 - val_accuracy: 0.6150
# Epoch 37/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6487 - accuracy: 0.6068 - val_loss: 0.6402 - val_accuracy: 0.6177
# Epoch 38/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6475 - accuracy: 0.6105 - val_loss: 0.6430 - val_accuracy: 0.6170
# Epoch 39/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6469 - accuracy: 0.6105 - val_loss: 0.6419 - val_accuracy: 0.6073
# Epoch 40/50
# 300/300 [==============================] - 3s 8ms/step - loss: 0.6474 - accuracy: 0.6107 - val_loss: 0.6407 - val_accuracy: 0.6200
# Epoch 41/50
# 300/300 [==============================] - 2s 7ms/step - loss: 0.6476 - accuracy: 0.6079 - val_loss: 0.6420 - val_accuracy: 0.6183
# Epoch 42/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6458 - accuracy: 0.6109 - val_loss: 0.6435 - val_accuracy: 0.6203
# Epoch 43/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6471 - accuracy: 0.6097 - val_loss: 0.6412 - val_accuracy: 0.6170
# Epoch 44/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6457 - accuracy: 0.6144 - val_loss: 0.6437 - val_accuracy: 0.6200
# Epoch 45/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6463 - accuracy: 0.6110 - val_loss: 0.6458 - val_accuracy: 0.6073
# Epoch 46/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6447 - accuracy: 0.6150 - val_loss: 0.6432 - val_accuracy: 0.6190
# Epoch 47/50
# 300/300 [==============================] - 2s 7ms/step - loss: 0.6455 - accuracy: 0.6097 - val_loss: 0.6422 - val_accuracy: 0.6120
# Epoch 48/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6454 - accuracy: 0.6108 - val_loss: 0.6423 - val_accuracy: 0.6193
# Epoch 49/50
# 300/300 [==============================] - 3s 10ms/step - loss: 0.6440 - accuracy: 0.6126 - val_loss: 0.6486 - val_accuracy: 0.6170
# Epoch 50/50
# 300/300 [==============================] - 3s 9ms/step - loss: 0.6443 - accuracy: 0.6131 - val_loss: 0.6425 - val_accuracy: 0.6223
# 94/94 - 0s - loss: 0.6343 - accuracy: 0.6213 - 305ms/epoch - 3ms/step
#
# Test accuracy: 0.6213333606719971
# Target: 0, Predicted label: [0]
# Execution time in seconds: 146.51379323005676
