# %%
import json
import time
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report,confusion_matrix,multilabel_confusion_matrix

# %%
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
DATA_PATH = "../data/all_mfcc_augmented.json"
TRAIN_PATH = "../data/train_mfcc_augmented.json"
TEST_PATH = "../data/test_mfcc_normal.json"
VAL_PATH = "../data/val_mfcc_augmented.json"

# %%
def load_all_data(data_path):
    """Loads train dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return  X, y

# %%
def load_train_data(train_path):
    """Loads train dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(train_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X_tr = np.array(data["mfcc"])
    y_tr = np.array(data["labels"])

    print("Train Data succesfully loaded!")

    return  X_tr, y_tr

# %%
def load_test_data(test_path):
    """Loads test dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(test_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X_ts = np.array(data["mfcc"])
    y_ts = np.array(data["labels"])

    print("Test Data succesfully loaded!")

    return  X_ts, y_ts

# %%
def load_val_data(val_path):
    """Loads validation dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(val_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X_v = np.array(data["mfcc"])
    y_v = np.array(data["labels"])

    print("Validation Data succesfully loaded!")

    return  X_v, y_v

# %%
def build_model(input_shape):
    
    # build network topology
    model = keras.Sequential([

        # input layer
        keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),

        # 1st dense layer
        keras.layers.Dense(512, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.3),

        # 2nd dense layer
        keras.layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.3),

        # 3rd dense layer
        keras.layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.3),

        # output layer
        keras.layers.Dense(2, activation='softmax')
    ])
    
    return model

# %%
def predict_single_sample(model, X, y):
    """Predict a single sample using the trained model
    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("\nTarget: {}, Predicted label: {}".format(y, predicted_index))
    print('\n')

# %%
def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %%
def plot(history, epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
X, y = load_all_data(DATA_PATH)
# Out:
# Data succesfully loaded!

# %%
X.shape
# Out:
# (468000, 1, 13)

# %%
X_train, y_train = load_train_data(TRAIN_PATH)
# Out:
# Train Data succesfully loaded!

# %%
X_train.shape
# Out:
# (288000, 1, 13)

# %%
X_test, y_test = load_test_data(TEST_PATH)
# Out:
# Test Data succesfully loaded!

# %%
X_val, y_val = load_val_data(VAL_PATH)
# Out:
# Validation Data succesfully loaded!

# %%
if __name__ == "__main__":
    
    startTime = time.time()

    # load data
    X, y = load_all_data(DATA_PATH)
    
    
    X_train, y_train = load_train_data(TRAIN_PATH)
    X_test, y_test = load_test_data(TEST_PATH)
    X_val, y_val = load_val_data(VAL_PATH)


    # build network topology
    model = keras.Sequential([

        # input layer
        keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),

        # 1st dense layer
        keras.layers.Dense(512, activation='relu'),

        # 2nd dense layer
        keras.layers.Dense(256, activation='relu'),

        # 3rd dense layer
        keras.layers.Dense(64, activation='relu'),

        # output layer
        keras.layers.Dense(2, activation='softmax')
    ])

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32, epochs=50)

    #plot_history(history)
    plot(history, 50)
    
    executionTime = (time.time() - startTime)
    print('Execution time in seconds: ' + str(executionTime))
# Out:
# Data succesfully loaded!
# Train Data succesfully loaded!
# Test Data succesfully loaded!
# Validation Data succesfully loaded!
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 13)                0
#
#  dense (Dense)               (None, 512)               7168
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dense_3 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 155,074
# Trainable params: 155,074
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 9000/9000 [==============================] - 19s 2ms/step - loss: 0.4310 - accuracy: 0.7979 - val_loss: 0.5242 - val_accuracy: 0.7711
# Epoch 2/50
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.3650 - accuracy: 0.8267 - val_loss: 0.5012 - val_accuracy: 0.7958
# Epoch 3/50
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.3364 - accuracy: 0.8401 - val_loss: 0.4937 - val_accuracy: 0.8024
# Epoch 4/50
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.3183 - accuracy: 0.8492 - val_loss: 0.4788 - val_accuracy: 0.8053
# Epoch 5/50
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.3046 - accuracy: 0.8562 - val_loss: 0.4901 - val_accuracy: 0.8044
# Epoch 6/50
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2922 - accuracy: 0.8624 - val_loss: 0.4943 - val_accuracy: 0.8003
# Epoch 7/50
# 9000/9000 [==============================] - 19s 2ms/step - loss: 0.2817 - accuracy: 0.8679 - val_loss: 0.5393 - val_accuracy: 0.8021
# Epoch 8/50
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2727 - accuracy: 0.8723 - val_loss: 0.5452 - val_accuracy: 0.7991
# Epoch 9/50
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.2647 - accuracy: 0.8765 - val_loss: 0.5955 - val_accuracy: 0.8004
# Epoch 10/50
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2580 - accuracy: 0.8797 - val_loss: 0.5435 - val_accuracy: 0.8022
# Epoch 11/50
# 9000/9000 [==============================] - 19s 2ms/step - loss: 0.2517 - accuracy: 0.8833 - val_loss: 0.6160 - val_accuracy: 0.7983
# Epoch 12/50
# 9000/9000 [==============================] - 19s 2ms/step - loss: 0.2459 - accuracy: 0.8868 - val_loss: 0.6704 - val_accuracy: 0.7960
# Epoch 13/50
# 9000/9000 [==============================] - 19s 2ms/step - loss: 0.2407 - accuracy: 0.8894 - val_loss: 0.6892 - val_accuracy: 0.7975
# Epoch 14/50
# 9000/9000 [==============================] - 19s 2ms/step - loss: 0.2358 - accuracy: 0.8918 - val_loss: 0.6604 - val_accuracy: 0.7946
# Epoch 15/50
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.2311 - accuracy: 0.8941 - val_loss: 0.7223 - val_accuracy: 0.7944
# Epoch 16/50
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.2268 - accuracy: 0.8964 - val_loss: 0.6421 - val_accuracy: 0.8005
# Epoch 17/50
# 9000/9000 [==============================] - 21s 2ms/step - loss: 0.2225 - accuracy: 0.8983 - val_loss: 0.6923 - val_accuracy: 0.7992
# Epoch 18/50
# 9000/9000 [==============================] - 21s 2ms/step - loss: 0.2188 - accuracy: 0.9008 - val_loss: 0.7024 - val_accuracy: 0.7936
# Epoch 19/50
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.2154 - accuracy: 0.9020 - val_loss: 0.7274 - val_accuracy: 0.7959
# Epoch 20/50
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.2119 - accuracy: 0.9043 - val_loss: 0.7271 - val_accuracy: 0.7945
# Epoch 21/50
# 9000/9000 [==============================] - 21s 2ms/step - loss: 0.2079 - accuracy: 0.9062 - val_loss: 0.8241 - val_accuracy: 0.7963
# Epoch 22/50
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.2049 - accuracy: 0.9077 - val_loss: 0.8083 - val_accuracy: 0.7902
# Epoch 23/50
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.2017 - accuracy: 0.9095 - val_loss: 0.8356 - val_accuracy: 0.7976
# Epoch 24/50
# 9000/9000 [==============================] - 21s 2ms/step - loss: 0.1992 - accuracy: 0.9108 - val_loss: 0.8273 - val_accuracy: 0.7951
# Epoch 25/50
# 9000/9000 [==============================] - 21s 2ms/step - loss: 0.1959 - accuracy: 0.9124 - val_loss: 0.9846 - val_accuracy: 0.7941
# Epoch 26/50
# 9000/9000 [==============================] - 21s 2ms/step - loss: 0.1932 - accuracy: 0.9138 - val_loss: 0.8589 - val_accuracy: 0.7940
# Epoch 27/50
# 9000/9000 [==============================] - 21s 2ms/step - loss: 0.1903 - accuracy: 0.9151 - val_loss: 0.9263 - val_accuracy: 0.7958
# Epoch 28/50
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.1879 - accuracy: 0.9164 - val_loss: 1.0456 - val_accuracy: 0.7913
# Epoch 29/50
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.1851 - accuracy: 0.9176 - val_loss: 1.0280 - val_accuracy: 0.7877
# Epoch 30/50
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.1833 - accuracy: 0.9187 - val_loss: 1.1094 - val_accuracy: 0.7909
# Epoch 31/50
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.1808 - accuracy: 0.9199 - val_loss: 1.0640 - val_accuracy: 0.7903
# Epoch 32/50
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.1786 - accuracy: 0.9211 - val_loss: 1.1982 - val_accuracy: 0.7938
# Epoch 33/50
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.1765 - accuracy: 0.9216 - val_loss: 1.2279 - val_accuracy: 0.7952
# Epoch 34/50
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.1744 - accuracy: 0.9229 - val_loss: 0.9473 - val_accuracy: 0.7961
# Epoch 35/50
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.1727 - accuracy: 0.9237 - val_loss: 1.2312 - val_accuracy: 0.7982
# Epoch 36/50
# 9000/9000 [==============================] - 23s 3ms/step - loss: 0.1702 - accuracy: 0.9248 - val_loss: 1.1451 - val_accuracy: 0.7935
# Epoch 37/50
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.1690 - accuracy: 0.9257 - val_loss: 1.2854 - val_accuracy: 0.7949
# Epoch 38/50
# 9000/9000 [==============================] - 23s 3ms/step - loss: 0.1664 - accuracy: 0.9267 - val_loss: 1.2023 - val_accuracy: 0.7913
# Epoch 39/50
# 9000/9000 [==============================] - 24s 3ms/step - loss: 0.1652 - accuracy: 0.9273 - val_loss: 1.1315 - val_accuracy: 0.7905
# Epoch 40/50
# 9000/9000 [==============================] - 25s 3ms/step - loss: 0.1631 - accuracy: 0.9284 - val_loss: 1.1653 - val_accuracy: 0.7965
# Epoch 41/50
# 9000/9000 [==============================] - 24s 3ms/step - loss: 0.1615 - accuracy: 0.9293 - val_loss: 1.2932 - val_accuracy: 0.7911
# Epoch 42/50
# 9000/9000 [==============================] - 23s 3ms/step - loss: 0.1596 - accuracy: 0.9306 - val_loss: 1.2958 - val_accuracy: 0.7968
# Epoch 43/50
# 9000/9000 [==============================] - 24s 3ms/step - loss: 0.1578 - accuracy: 0.9314 - val_loss: 1.4000 - val_accuracy: 0.7894
# Epoch 44/50
# 9000/9000 [==============================] - 23s 3ms/step - loss: 0.1567 - accuracy: 0.9317 - val_loss: 1.3070 - val_accuracy: 0.7935
# Epoch 45/50
# 9000/9000 [==============================] - 24s 3ms/step - loss: 0.1555 - accuracy: 0.9319 - val_loss: 1.2223 - val_accuracy: 0.7954
# Epoch 46/50
# 9000/9000 [==============================] - 23s 3ms/step - loss: 0.1534 - accuracy: 0.9332 - val_loss: 1.4080 - val_accuracy: 0.7908
# Epoch 47/50
# 9000/9000 [==============================] - 23s 3ms/step - loss: 0.1520 - accuracy: 0.9337 - val_loss: 1.1565 - val_accuracy: 0.7934
# Epoch 48/50
# 9000/9000 [==============================] - 23s 3ms/step - loss: 0.1505 - accuracy: 0.9345 - val_loss: 1.4575 - val_accuracy: 0.7931
# Epoch 49/50
# 9000/9000 [==============================] - 24s 3ms/step - loss: 0.1487 - accuracy: 0.9353 - val_loss: 1.5810 - val_accuracy: 0.7908
# Epoch 50/50
# 9000/9000 [==============================] - 24s 3ms/step - loss: 0.1476 - accuracy: 0.9364 - val_loss: 1.5466 - val_accuracy: 0.7881
# Execution time in seconds: 1077.6692235469818

# %%
#solving overfitting

if __name__ == "__main__":
    
    startTime = time.time()


    # load data
    X, y = load_all_data(DATA_PATH)
    
    #load the data splitted into train, test and validation
    X_train, y_train = load_train_data(TRAIN_PATH)
    X_test, y_test = load_test_data(TEST_PATH)
    X_val, y_val = load_val_data(VAL_PATH)
    
    input_shape = (X.shape[1], X.shape[2])
    model = build_model(input_shape)

    

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32, epochs=100)

    # plot accuracy and error as a function of the epochs
    #plot_history(history)
    plot(history,100)
    
    
    #evaluate on train set
    train_loss, train_acc = model.evaluate(X_train, y_train, verbose=2)
    print('Train accuracy:', train_acc)
    print('\n')
    
    
    # evaluate model on validation set
    val_loss, val_acc = model.evaluate(X_val, y_val, verbose=2)
    print('Validation accuracy:', val_acc)
    print('\n')

    
     # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('Test accuracy:', test_acc)
    print('\n')

    # pick a sample to predict from the test set
    X_to_predict = X_test[150]
    y_to_predict = y_test[150]

    # prediction for a single sample sample
    predict_single_sample(model, X_to_predict, y_to_predict)

    
    # take the entire test set for prediction
    pred = model.predict(X_test, batch_size = 32, verbose = 2)
    y_pred = pred > 0.70
    p_i = np.argmax(y_pred, axis=1)
    print("\n Target: {}, Predicted label: {}".format(y_test, p_i))
    
    results=pd.DataFrame({"Target":y_test,
                      "Predicted Labels":p_i})
    results.to_csv("../predictions/mlp_augmented_result.csv",index=False)
    
    
    executionTime = (time.time() - startTime)
    print('Execution time in seconds: ' + str(executionTime))
# Out:
# Data succesfully loaded!
# Train Data succesfully loaded!
# Test Data succesfully loaded!
# Validation Data succesfully loaded!
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 13)                0
#
#  dense (Dense)               (None, 512)               7168
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 155,074
# Trainable params: 155,074
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.9569 - accuracy: 0.6634 - val_loss: 0.7343 - val_accuracy: 0.7763
# Epoch 2/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.5425 - accuracy: 0.7959 - val_loss: 0.5663 - val_accuracy: 0.7850
# Epoch 3/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.4454 - accuracy: 0.8179 - val_loss: 0.5188 - val_accuracy: 0.7960
# Epoch 4/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.4008 - accuracy: 0.8303 - val_loss: 0.5090 - val_accuracy: 0.8019
# Epoch 5/100
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.3766 - accuracy: 0.8395 - val_loss: 0.5256 - val_accuracy: 0.8045
# Epoch 6/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.3623 - accuracy: 0.8453 - val_loss: 0.5171 - val_accuracy: 0.8059
# Epoch 7/100
# 9000/9000 [==============================] - 55s 6ms/step - loss: 0.3537 - accuracy: 0.8494 - val_loss: 0.5076 - val_accuracy: 0.8066
# Epoch 8/100
# 9000/9000 [==============================] - 70s 8ms/step - loss: 0.3478 - accuracy: 0.8514 - val_loss: 0.5170 - val_accuracy: 0.8048
# Epoch 9/100
# 9000/9000 [==============================] - 77s 9ms/step - loss: 0.3442 - accuracy: 0.8538 - val_loss: 0.5050 - val_accuracy: 0.8074
# Epoch 10/100
# 9000/9000 [==============================] - 77s 9ms/step - loss: 0.3409 - accuracy: 0.8554 - val_loss: 0.5204 - val_accuracy: 0.8090
# Epoch 11/100
# 9000/9000 [==============================] - 73s 8ms/step - loss: 0.3389 - accuracy: 0.8563 - val_loss: 0.5236 - val_accuracy: 0.8090
# Epoch 12/100
# 9000/9000 [==============================] - 76s 8ms/step - loss: 0.3366 - accuracy: 0.8577 - val_loss: 0.5139 - val_accuracy: 0.8042
# Epoch 13/100
# 9000/9000 [==============================] - 76s 8ms/step - loss: 0.3352 - accuracy: 0.8577 - val_loss: 0.5217 - val_accuracy: 0.8087
# Epoch 14/100
# 9000/9000 [==============================] - 69s 8ms/step - loss: 0.3344 - accuracy: 0.8581 - val_loss: 0.5049 - val_accuracy: 0.8081
# Epoch 15/100
# 9000/9000 [==============================] - 67s 7ms/step - loss: 0.3325 - accuracy: 0.8603 - val_loss: 0.5192 - val_accuracy: 0.8069
# Epoch 16/100
# 9000/9000 [==============================] - 68s 8ms/step - loss: 0.3319 - accuracy: 0.8599 - val_loss: 0.5300 - val_accuracy: 0.8069
# Epoch 17/100
# 9000/9000 [==============================] - 68s 8ms/step - loss: 0.3315 - accuracy: 0.8601 - val_loss: 0.5101 - val_accuracy: 0.8060
# Epoch 18/100
# 9000/9000 [==============================] - 68s 8ms/step - loss: 0.3297 - accuracy: 0.8612 - val_loss: 0.5156 - val_accuracy: 0.8057
# Epoch 19/100
# 9000/9000 [==============================] - 67s 7ms/step - loss: 0.3290 - accuracy: 0.8615 - val_loss: 0.5539 - val_accuracy: 0.8057
# Epoch 20/100
# 9000/9000 [==============================] - 67s 7ms/step - loss: 0.3285 - accuracy: 0.8617 - val_loss: 0.5136 - val_accuracy: 0.8081
# Epoch 21/100
# 9000/9000 [==============================] - 67s 7ms/step - loss: 0.3268 - accuracy: 0.8629 - val_loss: 0.5247 - val_accuracy: 0.8075
# Epoch 22/100
# 9000/9000 [==============================] - 74s 8ms/step - loss: 0.3269 - accuracy: 0.8630 - val_loss: 0.5277 - val_accuracy: 0.8041
# Epoch 23/100
# 9000/9000 [==============================] - 71s 8ms/step - loss: 0.3266 - accuracy: 0.8628 - val_loss: 0.4991 - val_accuracy: 0.8073
# Epoch 24/100
# 9000/9000 [==============================] - 70s 8ms/step - loss: 0.3247 - accuracy: 0.8639 - val_loss: 0.5206 - val_accuracy: 0.8140
# Epoch 25/100
# 9000/9000 [==============================] - 72s 8ms/step - loss: 0.3251 - accuracy: 0.8639 - val_loss: 0.5305 - val_accuracy: 0.8030
# Epoch 26/100
# 9000/9000 [==============================] - 75s 8ms/step - loss: 0.3242 - accuracy: 0.8644 - val_loss: 0.5044 - val_accuracy: 0.8042
# Epoch 27/100
# 9000/9000 [==============================] - 69s 8ms/step - loss: 0.3232 - accuracy: 0.8649 - val_loss: 0.5087 - val_accuracy: 0.8089
# Epoch 28/100
# 9000/9000 [==============================] - 65s 7ms/step - loss: 0.3231 - accuracy: 0.8654 - val_loss: 0.5158 - val_accuracy: 0.8076
# Epoch 29/100
# 9000/9000 [==============================] - 77s 9ms/step - loss: 0.3225 - accuracy: 0.8659 - val_loss: 0.5074 - val_accuracy: 0.8097
# Epoch 30/100
# 9000/9000 [==============================] - 79s 9ms/step - loss: 0.3216 - accuracy: 0.8660 - val_loss: 0.5295 - val_accuracy: 0.8063
# Epoch 31/100
# 9000/9000 [==============================] - 75s 8ms/step - loss: 0.3215 - accuracy: 0.8662 - val_loss: 0.5103 - val_accuracy: 0.8097
# Epoch 32/100
# 9000/9000 [==============================] - 77s 9ms/step - loss: 0.3206 - accuracy: 0.8662 - val_loss: 0.5269 - val_accuracy: 0.8052
# Epoch 33/100
# 9000/9000 [==============================] - 79s 9ms/step - loss: 0.3204 - accuracy: 0.8665 - val_loss: 0.5438 - val_accuracy: 0.7991
# Epoch 34/100
# 9000/9000 [==============================] - 72s 8ms/step - loss: 0.3203 - accuracy: 0.8668 - val_loss: 0.5337 - val_accuracy: 0.8105
# Epoch 35/100
# 9000/9000 [==============================] - 72s 8ms/step - loss: 0.3184 - accuracy: 0.8676 - val_loss: 0.5193 - val_accuracy: 0.8055
# Epoch 36/100
# 9000/9000 [==============================] - 70s 8ms/step - loss: 0.3182 - accuracy: 0.8680 - val_loss: 0.5134 - val_accuracy: 0.8076
# Epoch 37/100
# 9000/9000 [==============================] - 75s 8ms/step - loss: 0.3183 - accuracy: 0.8677 - val_loss: 0.5508 - val_accuracy: 0.8042
# Epoch 38/100
# 9000/9000 [==============================] - 77s 9ms/step - loss: 0.3171 - accuracy: 0.8684 - val_loss: 0.4974 - val_accuracy: 0.8122
# Epoch 39/100
# 9000/9000 [==============================] - 74s 8ms/step - loss: 0.3165 - accuracy: 0.8685 - val_loss: 0.5358 - val_accuracy: 0.8073
# Epoch 40/100
# 9000/9000 [==============================] - 72s 8ms/step - loss: 0.3165 - accuracy: 0.8688 - val_loss: 0.4899 - val_accuracy: 0.8113
# Epoch 41/100
# 9000/9000 [==============================] - 76s 8ms/step - loss: 0.3159 - accuracy: 0.8692 - val_loss: 0.5416 - val_accuracy: 0.8086
# Epoch 42/100
# 9000/9000 [==============================] - 74s 8ms/step - loss: 0.3157 - accuracy: 0.8691 - val_loss: 0.5360 - val_accuracy: 0.8070
# Epoch 43/100
# 9000/9000 [==============================] - 71s 8ms/step - loss: 0.3142 - accuracy: 0.8705 - val_loss: 0.4906 - val_accuracy: 0.8070
# Epoch 44/100
# 9000/9000 [==============================] - 71s 8ms/step - loss: 0.3149 - accuracy: 0.8703 - val_loss: 0.5528 - val_accuracy: 0.8081
# Epoch 45/100
# 9000/9000 [==============================] - 69s 8ms/step - loss: 0.3146 - accuracy: 0.8695 - val_loss: 0.5232 - val_accuracy: 0.8075
# Epoch 46/100
# 9000/9000 [==============================] - 71s 8ms/step - loss: 0.3134 - accuracy: 0.8700 - val_loss: 0.5326 - val_accuracy: 0.8073
# Epoch 47/100
# 9000/9000 [==============================] - 71s 8ms/step - loss: 0.3137 - accuracy: 0.8704 - val_loss: 0.5175 - val_accuracy: 0.8091
# Epoch 48/100
# 9000/9000 [==============================] - 73s 8ms/step - loss: 0.3130 - accuracy: 0.8701 - val_loss: 0.5269 - val_accuracy: 0.8108
# Epoch 49/100
# 9000/9000 [==============================] - 74s 8ms/step - loss: 0.3139 - accuracy: 0.8701 - val_loss: 0.5189 - val_accuracy: 0.8033
# Epoch 50/100
# 9000/9000 [==============================] - 78s 9ms/step - loss: 0.3128 - accuracy: 0.8708 - val_loss: 0.5294 - val_accuracy: 0.8056
# Epoch 51/100
# 9000/9000 [==============================] - 75s 8ms/step - loss: 0.3120 - accuracy: 0.8714 - val_loss: 0.4962 - val_accuracy: 0.8068
# Epoch 52/100
# 9000/9000 [==============================] - 75s 8ms/step - loss: 0.3122 - accuracy: 0.8709 - val_loss: 0.5051 - val_accuracy: 0.8056
# Epoch 53/100
# 9000/9000 [==============================] - 76s 8ms/step - loss: 0.3124 - accuracy: 0.8713 - val_loss: 0.4952 - val_accuracy: 0.8073
# Epoch 54/100
# 9000/9000 [==============================] - 77s 9ms/step - loss: 0.3112 - accuracy: 0.8717 - val_loss: 0.5467 - val_accuracy: 0.8053
# Epoch 55/100
# 9000/9000 [==============================] - 78s 9ms/step - loss: 0.3107 - accuracy: 0.8715 - val_loss: 0.5237 - val_accuracy: 0.8013
# Epoch 56/100
# 9000/9000 [==============================] - 75s 8ms/step - loss: 0.3113 - accuracy: 0.8711 - val_loss: 0.5055 - val_accuracy: 0.8083
# Epoch 57/100
# 9000/9000 [==============================] - 70s 8ms/step - loss: 0.3106 - accuracy: 0.8717 - val_loss: 0.5347 - val_accuracy: 0.8046
# Epoch 58/100
# 9000/9000 [==============================] - 70s 8ms/step - loss: 0.3101 - accuracy: 0.8723 - val_loss: 0.5224 - val_accuracy: 0.8118
# Epoch 59/100
# 9000/9000 [==============================] - 74s 8ms/step - loss: 0.3101 - accuracy: 0.8720 - val_loss: 0.5266 - val_accuracy: 0.8104
# Epoch 60/100
# 9000/9000 [==============================] - 70s 8ms/step - loss: 0.3096 - accuracy: 0.8721 - val_loss: 0.4731 - val_accuracy: 0.8166
# Epoch 61/100
# 7433/9000 [=======================>......] - ETA: 11s - loss: 0.3097 - accuracy: 0.8731
