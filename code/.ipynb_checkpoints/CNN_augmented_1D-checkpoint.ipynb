# %%
import json
import numpy as np
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import time

# %%
DATA_PATH = "../data/all_mfcc_augmented.json"
TRAIN_PATH = "../data/train_mfcc_augmented.json"
TEST_PATH = "../data/test_mfcc_augmented.json"
VAL_PATH = "../data/val_mfcc_augmented.json"

# %%
def load_all_data(data_path):
    """Loads train dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return  X, y

# %%
def load_train_data(train_path):
    """Loads train dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(train_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X_tr = np.array(data["mfcc"])
    y_tr = np.array(data["labels"])

    print("Train Data succesfully loaded!")

    return  X_tr, y_tr

# %%
def load_test_data(test_path):
    """Loads test dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(test_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X_ts = np.array(data["mfcc"])
    y_ts = np.array(data["labels"])

    print("Test Data succesfully loaded!")

    return  X_ts, y_ts

# %%
def load_val_data(val_path):
    """Loads validation dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(val_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X_v = np.array(data["mfcc"])
    y_v = np.array(data["labels"])

    print("Validation Data succesfully loaded!")

    return  X_v, y_v

# %%
def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %%
def plot(history, epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def prepare_datasets():
    """Loads data and splits it into train, validation and test sets.
    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    #X, y = load_all_data(DATA_PATH)

    # create train, validation and test split
    X_train, y_train = load_train_data(TRAIN_PATH)
    X_test, y_test = load_test_data(TEST_PATH)
    X_val, y_val = load_val_data(VAL_PATH)

    
    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_val = X_val[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
def build_model(input_shape):
    """Generates CNN model
    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (1, 1), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((1, 1), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())
    

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (1, 1), activation='relu'))
    model.add(keras.layers.MaxPooling2D((1, 1), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (1, 1), activation='relu'))
    model.add(keras.layers.MaxPooling2D((1, 1), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())
    

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(2, activation='softmax'))

    return model

# %%
def predict(model, X, y):
    """Predict a single sample using the trained model
    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))

# %%
X_train, X_val, X_test, y_train, y_val, y_test = prepare_datasets()
# Out:
# Train Data succesfully loaded!
# Test Data succesfully loaded!
# Validation Data succesfully loaded!

# %%
X_train.shape
# Out:
# (288000, 1, 13, 1)

# %%
if __name__ == "__main__":
    
    startTime = time.time()

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets()
    print(X_train.shape)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=100)

    # plot accuracy/error for training and validation
    plot_history(history)
    plot(history, 100)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[50]
    y_to_predict = y_test[50]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
    
    executionTime = (time.time() - startTime)
    print('Execution time in seconds: ' + str(executionTime))
# Out:
# Train Data succesfully loaded!
# Test Data succesfully loaded!
# Validation Data succesfully loaded!
# (288000, 1, 13, 1)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 1, 13, 32)         64
#
#  max_pooling2d (MaxPooling2D  (None, 1, 7, 32)         0
#  )
#
#  batch_normalization (BatchN  (None, 1, 7, 32)         128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 1, 7, 32)          1056
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 4, 32)         0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 1, 4, 32)         128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 1, 4, 32)          1056
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 2, 32)         0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 1, 2, 32)         128
#  hNormalization)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 6,850
# Trainable params: 6,658
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/100
# 9000/9000 [==============================] - 33s 3ms/step - loss: 0.6701 - accuracy: 0.5767 - val_loss: 0.6593 - val_accuracy: 0.5839
# Epoch 2/100
# 9000/9000 [==============================] - 32s 4ms/step - loss: 0.6606 - accuracy: 0.5858 - val_loss: 0.6614 - val_accuracy: 0.5832
# Epoch 3/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6595 - accuracy: 0.5872 - val_loss: 0.6608 - val_accuracy: 0.5838
# Epoch 4/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6590 - accuracy: 0.5870 - val_loss: 0.6583 - val_accuracy: 0.5894
# Epoch 5/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6586 - accuracy: 0.5882 - val_loss: 0.6589 - val_accuracy: 0.5885
# Epoch 6/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6589 - accuracy: 0.5875 - val_loss: 0.6591 - val_accuracy: 0.5894
# Epoch 7/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6583 - accuracy: 0.5886 - val_loss: 0.6615 - val_accuracy: 0.5849
# Epoch 8/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6582 - accuracy: 0.5881 - val_loss: 0.6610 - val_accuracy: 0.5834
# Epoch 9/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6583 - accuracy: 0.5884 - val_loss: 0.6600 - val_accuracy: 0.5869
# Epoch 10/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6580 - accuracy: 0.5885 - val_loss: 0.6612 - val_accuracy: 0.5839
# Epoch 11/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6582 - accuracy: 0.5888 - val_loss: 0.6606 - val_accuracy: 0.5883
# Epoch 12/100
# 9000/9000 [==============================] - 30s 3ms/step - loss: 0.6579 - accuracy: 0.5896 - val_loss: 0.6597 - val_accuracy: 0.5865
# Epoch 13/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6579 - accuracy: 0.5888 - val_loss: 0.6615 - val_accuracy: 0.5838
# Epoch 14/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6578 - accuracy: 0.5898 - val_loss: 0.6605 - val_accuracy: 0.5865
# Epoch 15/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6578 - accuracy: 0.5898 - val_loss: 0.6589 - val_accuracy: 0.5902
# Epoch 16/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6578 - accuracy: 0.5893 - val_loss: 0.6596 - val_accuracy: 0.5877
# Epoch 17/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6575 - accuracy: 0.5894 - val_loss: 0.6605 - val_accuracy: 0.5894
# Epoch 18/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6579 - accuracy: 0.5895 - val_loss: 0.6636 - val_accuracy: 0.5822
# Epoch 19/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6576 - accuracy: 0.5896 - val_loss: 0.6620 - val_accuracy: 0.5837
# Epoch 20/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6574 - accuracy: 0.5893 - val_loss: 0.6617 - val_accuracy: 0.5855
# Epoch 21/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6575 - accuracy: 0.5880 - val_loss: 0.6612 - val_accuracy: 0.5841
# Epoch 22/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6575 - accuracy: 0.5891 - val_loss: 0.6594 - val_accuracy: 0.5883
# Epoch 23/100
# 9000/9000 [==============================] - 31s 3ms/step - loss: 0.6575 - accuracy: 0.5889 - val_loss: 0.6616 - val_accuracy: 0.5828
# Epoch 24/100
# 9000/9000 [==============================] - 23s 3ms/step - loss: 0.6574 - accuracy: 0.5890 - val_loss: 0.6625 - val_accuracy: 0.5850
# Epoch 25/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6573 - accuracy: 0.5894 - val_loss: 0.6628 - val_accuracy: 0.5839
# Epoch 26/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6574 - accuracy: 0.5892 - val_loss: 0.6627 - val_accuracy: 0.5840
# Epoch 27/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6575 - accuracy: 0.5893 - val_loss: 0.6602 - val_accuracy: 0.5863
# Epoch 28/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6572 - accuracy: 0.5895 - val_loss: 0.6628 - val_accuracy: 0.5836
# Epoch 29/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6575 - accuracy: 0.5893 - val_loss: 0.6614 - val_accuracy: 0.5838
# Epoch 30/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6571 - accuracy: 0.5893 - val_loss: 0.6622 - val_accuracy: 0.5845
# Epoch 31/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6574 - accuracy: 0.5902 - val_loss: 0.6623 - val_accuracy: 0.5844
# Epoch 32/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6572 - accuracy: 0.5899 - val_loss: 0.6612 - val_accuracy: 0.5862
# Epoch 33/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6570 - accuracy: 0.5891 - val_loss: 0.6610 - val_accuracy: 0.5867
# Epoch 34/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6569 - accuracy: 0.5897 - val_loss: 0.6606 - val_accuracy: 0.5865
# Epoch 35/100
# 9000/9000 [==============================] - 23s 3ms/step - loss: 0.6572 - accuracy: 0.5902 - val_loss: 0.6602 - val_accuracy: 0.5842
# Epoch 36/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6570 - accuracy: 0.5894 - val_loss: 0.6630 - val_accuracy: 0.5822
# Epoch 37/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6570 - accuracy: 0.5896 - val_loss: 0.6607 - val_accuracy: 0.5873
# Epoch 38/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6570 - accuracy: 0.5897 - val_loss: 0.6615 - val_accuracy: 0.5848
# Epoch 39/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6567 - accuracy: 0.5899 - val_loss: 0.6604 - val_accuracy: 0.5872
# Epoch 40/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6570 - accuracy: 0.5899 - val_loss: 0.6608 - val_accuracy: 0.5856
# Epoch 41/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6570 - accuracy: 0.5897 - val_loss: 0.6606 - val_accuracy: 0.5869
# Epoch 42/100
# 9000/9000 [==============================] - 23s 3ms/step - loss: 0.6570 - accuracy: 0.5901 - val_loss: 0.6605 - val_accuracy: 0.5854
# Epoch 43/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6571 - accuracy: 0.5893 - val_loss: 0.6598 - val_accuracy: 0.5845
# Epoch 44/100
# 9000/9000 [==============================] - 23s 3ms/step - loss: 0.6569 - accuracy: 0.5901 - val_loss: 0.6616 - val_accuracy: 0.5840
# Epoch 45/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6570 - accuracy: 0.5887 - val_loss: 0.6610 - val_accuracy: 0.5858
# Epoch 46/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6570 - accuracy: 0.5901 - val_loss: 0.6598 - val_accuracy: 0.5875
# Epoch 47/100
# 9000/9000 [==============================] - 23s 2ms/step - loss: 0.6569 - accuracy: 0.5899 - val_loss: 0.6606 - val_accuracy: 0.5847
# Epoch 48/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6569 - accuracy: 0.5895 - val_loss: 0.6597 - val_accuracy: 0.5879
# Epoch 49/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6570 - accuracy: 0.5900 - val_loss: 0.6611 - val_accuracy: 0.5857
# Epoch 50/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6569 - accuracy: 0.5896 - val_loss: 0.6614 - val_accuracy: 0.5854
# Epoch 51/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6568 - accuracy: 0.5889 - val_loss: 0.6621 - val_accuracy: 0.5865
# Epoch 52/100
# 9000/9000 [==============================] - 23s 3ms/step - loss: 0.6570 - accuracy: 0.5898 - val_loss: 0.6602 - val_accuracy: 0.5858
# Epoch 53/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6566 - accuracy: 0.5905 - val_loss: 0.6609 - val_accuracy: 0.5874
# Epoch 54/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6567 - accuracy: 0.5896 - val_loss: 0.6609 - val_accuracy: 0.5869
# Epoch 55/100
# 9000/9000 [==============================] - 22s 2ms/step - loss: 0.6568 - accuracy: 0.5901 - val_loss: 0.6592 - val_accuracy: 0.5883
# Epoch 56/100
# 9000/9000 [==============================] - 24s 3ms/step - loss: 0.6568 - accuracy: 0.5901 - val_loss: 0.6627 - val_accuracy: 0.5853
# Epoch 57/100
# 9000/9000 [==============================] - 26s 3ms/step - loss: 0.6571 - accuracy: 0.5902 - val_loss: 0.6617 - val_accuracy: 0.5841
# Epoch 58/100
# 9000/9000 [==============================] - 26s 3ms/step - loss: 0.6567 - accuracy: 0.5897 - val_loss: 0.6595 - val_accuracy: 0.5867
# Epoch 59/100
# 9000/9000 [==============================] - 26s 3ms/step - loss: 0.6567 - accuracy: 0.5903 - val_loss: 0.6633 - val_accuracy: 0.5811
# Epoch 60/100
# 9000/9000 [==============================] - 26s 3ms/step - loss: 0.6569 - accuracy: 0.5888 - val_loss: 0.6619 - val_accuracy: 0.5847
# Epoch 61/100
# 9000/9000 [==============================] - 26s 3ms/step - loss: 0.6571 - accuracy: 0.5899 - val_loss: 0.6611 - val_accuracy: 0.5864
# Epoch 62/100
# 9000/9000 [==============================] - 26s 3ms/step - loss: 0.6566 - accuracy: 0.5906 - val_loss: 0.6600 - val_accuracy: 0.5880
# Epoch 63/100
# 9000/9000 [==============================] - 26s 3ms/step - loss: 0.6569 - accuracy: 0.5900 - val_loss: 0.6617 - val_accuracy: 0.5861
# Epoch 64/100
# 9000/9000 [==============================] - 26s 3ms/step - loss: 0.6567 - accuracy: 0.5908 - val_loss: 0.6614 - val_accuracy: 0.5842
# Epoch 65/100
# 9000/9000 [==============================] - 26s 3ms/step - loss: 0.6567 - accuracy: 0.5907 - val_loss: 0.6608 - val_accuracy: 0.5857
# Epoch 66/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6565 - accuracy: 0.5902 - val_loss: 0.6618 - val_accuracy: 0.5851
# Epoch 67/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6567 - accuracy: 0.5899 - val_loss: 0.6616 - val_accuracy: 0.5852
# Epoch 68/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6566 - accuracy: 0.5904 - val_loss: 0.6613 - val_accuracy: 0.5845
# Epoch 69/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6567 - accuracy: 0.5901 - val_loss: 0.6601 - val_accuracy: 0.5868
# Epoch 70/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6565 - accuracy: 0.5901 - val_loss: 0.6623 - val_accuracy: 0.5835
# Epoch 71/100
# 9000/9000 [==============================] - 19s 2ms/step - loss: 0.6565 - accuracy: 0.5896 - val_loss: 0.6632 - val_accuracy: 0.5846
# Epoch 72/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6567 - accuracy: 0.5902 - val_loss: 0.6616 - val_accuracy: 0.5855
# Epoch 73/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6567 - accuracy: 0.5893 - val_loss: 0.6599 - val_accuracy: 0.5882
# Epoch 74/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6564 - accuracy: 0.5900 - val_loss: 0.6625 - val_accuracy: 0.5854
# Epoch 75/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6567 - accuracy: 0.5901 - val_loss: 0.6604 - val_accuracy: 0.5847
# Epoch 76/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6565 - accuracy: 0.5905 - val_loss: 0.6592 - val_accuracy: 0.5886
# Epoch 77/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6567 - accuracy: 0.5898 - val_loss: 0.6605 - val_accuracy: 0.5871
# Epoch 78/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6565 - accuracy: 0.5902 - val_loss: 0.6618 - val_accuracy: 0.5869
# Epoch 79/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6566 - accuracy: 0.5899 - val_loss: 0.6595 - val_accuracy: 0.5865
# Epoch 80/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6566 - accuracy: 0.5903 - val_loss: 0.6625 - val_accuracy: 0.5828
# Epoch 81/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6565 - accuracy: 0.5909 - val_loss: 0.6597 - val_accuracy: 0.5876
# Epoch 82/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6566 - accuracy: 0.5901 - val_loss: 0.6617 - val_accuracy: 0.5832
# Epoch 83/100
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.6567 - accuracy: 0.5898 - val_loss: 0.6599 - val_accuracy: 0.5875
# Epoch 84/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6565 - accuracy: 0.5901 - val_loss: 0.6627 - val_accuracy: 0.5824
# Epoch 85/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6565 - accuracy: 0.5906 - val_loss: 0.6619 - val_accuracy: 0.5826
# Epoch 86/100
# 9000/9000 [==============================] - 21s 2ms/step - loss: 0.6563 - accuracy: 0.5904 - val_loss: 0.6612 - val_accuracy: 0.5845
# Epoch 87/100
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.6564 - accuracy: 0.5905 - val_loss: 0.6599 - val_accuracy: 0.5865
# Epoch 88/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6563 - accuracy: 0.5904 - val_loss: 0.6629 - val_accuracy: 0.5828
# Epoch 89/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6564 - accuracy: 0.5906 - val_loss: 0.6586 - val_accuracy: 0.5891
# Epoch 90/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6563 - accuracy: 0.5903 - val_loss: 0.6630 - val_accuracy: 0.5812
# Epoch 91/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6565 - accuracy: 0.5899 - val_loss: 0.6602 - val_accuracy: 0.5872
# Epoch 92/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6561 - accuracy: 0.5907 - val_loss: 0.6607 - val_accuracy: 0.5864
# Epoch 93/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6563 - accuracy: 0.5902 - val_loss: 0.6614 - val_accuracy: 0.5848
# Epoch 94/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6564 - accuracy: 0.5896 - val_loss: 0.6646 - val_accuracy: 0.5836
# Epoch 95/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6564 - accuracy: 0.5895 - val_loss: 0.6639 - val_accuracy: 0.5832
# Epoch 96/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6564 - accuracy: 0.5902 - val_loss: 0.6613 - val_accuracy: 0.5879
# Epoch 97/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6567 - accuracy: 0.5908 - val_loss: 0.6623 - val_accuracy: 0.5855
# Epoch 98/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6566 - accuracy: 0.5900 - val_loss: 0.6611 - val_accuracy: 0.5870
# Epoch 99/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6565 - accuracy: 0.5908 - val_loss: 0.6612 - val_accuracy: 0.5864
# Epoch 100/100
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6563 - accuracy: 0.5902 - val_loss: 0.6601 - val_accuracy: 0.5876
# 2813/2813 - 2s - loss: 0.6534 - accuracy: 0.5961 - 2s/epoch - 777us/step
#
# Test accuracy: 0.5961111187934875
# Target: 0, Predicted label: [0]
# Execution time in seconds: 2345.042152404785
